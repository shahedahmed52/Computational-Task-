# %%
! pip install  pyopenms
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# ...
#    ---------------------------------------- 0.0/48.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/48.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/48.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/48.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/48.3 MB ? eta -:--:--
#    ---------------------------------------- 0.5/48.3 MB 598.5 kB/s eta 0:01:20
#    ---------------------------------------- 0.5/48.3 MB 598.5 kB/s eta 0:01:20
#     --------------------------------------- 0.8/48.3 MB 609.6 kB/s eta 0:01:19
#     --------------------------------------- 0.8/48.3 MB 609.6 kB/s eta 0:01:19
#     --------------------------------------- 1.0/48.3 MB 636.8 kB/s eta 0:01:15
#    - -------------------------------------- 1.3/48.3 MB 691.7 kB/s eta 0:01:08
# ...

# %%
import pyopenms

residue_db = pyopenms.ResidueDB()



print(f" (Valine): {v_mass:.2f} ")
print(f"(Alanine): {a_mass:.2f} ")
print(f" (Lysine): {k_mass:.2f} ")

total_individual_mass = v_mass + a_mass + k_mass + a_mass
print(f"\nSum :(V + A + K + A): {total_individual_mass:.2f} ")

sequence = pyopenms.AASequence.fromString("VAKA")
mass_vaka = sequence.getMonoWeight()
print(f"The exact mass of VAKA  : {mass_vaka:.2f} ")

is_correct = (mass_vaka == total_individual_mass)
print(f"\nIs the equation correct? {is_correct}")

water_mass = 18.01528  
num_peptide_bonds = 3 
adjusted_mass = total_individual_mass - num_peptide_bonds * water_mass

print(f"Adjusted mass (accounting for water loss from peptide bonds): {adjusted_mass:.2f} Da")

is_correct_adjusted = (mass_vaka == adjusted_mass)
print(f"Is the equation correct after adjusting for water loss? {is_correct_adjusted}")
# Out:
#  (Valine): 117.08
# (Alanine): 89.05
#  (Lysine): 146.11
#
# Sum :(V + A + K + A): 441.28
# The exact mass of VAKA  : 387.25
#
# Is the equation correct? False
# Adjusted mass (accounting for water loss from peptide bonds): 387.23 Da
# Is the equation correct after adjusting for water loss? False
